# %% [markdown]
# **Import the required Modules:**

# %%
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# **See the structure of URL:**

# %%
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=1
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=2

# %%
base_url ='https://www.flipkart.com/search?q=apple%20watch&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

# %% [markdown]
# **Create List for store the Data**

# %%
pd_name = []
price =[]
ratings = []
warranty = []
ratingsno = []
reviewsno = []
features = []
for i in range(1,3):
  time.sleep(3)
  req = requests.get(base_url+str(i))
  soup = BeautifulSoup(req.text,'html')

  #product name
  pdt_name = soup.findAll('div',attrs={'class':'_4rR01T'})
  [pd_name.append(i.text) for i in pdt_name]

  #price
  p = soup.findAll('div',attrs={'class':'_30jeq3 _1_WHN1'})
  [price.append(i.text) for i in p]

  #ratings
  r = soup.findAll('div',attrs={'class':'gUuXy-'})
  [ratings.append(i.span.div.text) for i in r]

  #warranty
  wl = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  w = [i.findAll('li')[-1] for i in wl]
  [warranty.append(i.text) for i in w]

  #number of ratings and reviews
  a = soup.findAll('span',attrs={'class':'_2_R_DZ'})
  for i in a:
    a = i.text.split('&')
    ratingsno.append(a[0].split(" ")[0])
    reviewsno.append(a[1].split(" ")[0])

  #features
  prop = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  for i in prop:
    a = i.findAll('li')[0:-2]
    b =[i.text for i in a]
    features.append(','.join(b))

# %%
print('pd_name= ',len(pd_name))
print('price = ',len(price))
print('ratings = ',len(ratings))
print('warranty = ',len(warranty))
print('ratingsno =',len(ratingsno))
print('reviewsno = ',len(reviewsno))
print('features = ',len(features))
# Out:
# pd_name=  48
# price =  48
# ratings =  48
# warranty =  48
# ratingsno = 48
# reviewsno =  48
# features =  48

# %%
data = pd.DataFrame({'Product':pd_name,
                     'Price':price,
                     'Ratings':ratings,
                     'Warranty':warranty,
                     'No of Ratings':ratingsno,
                     'No of Reviews':reviewsno,
                     'Features':features})
data
# Out:
#                                               Product    Price Ratings  \
# 0   APPLE Watch Series 3 GPS - MTF32HN/A 42 mm Spa...  ₹18,850     4.6
# 1   APPLE Watch Series 3 GPS - MTF02HN/A 38 mm Spa...  ₹16,850     4.6
# 2   APPLE Watch Series 3 GPS - MTEY2HN/A 38 mm Sil...  ₹16,850     4.6
# 3   APPLE Watch Series 3 MTF22HN/A 42 mm Silver Al...  ₹18,850     4.6
# 4   APPLE Watch SE GPS MKQ03HN/A 40 mm Aluminium Case  ₹29,850     4.6
# 5   APPLE Watch SE GPS + Cellular MKT33HN/A 44 mm ...  ₹36,850     4.6
# 6   APPLE Watch Series 7 GPS MKN63HN/A 45 mm Alumi...  ₹44,850     4.5
# 38  1 Year Manufacturer Warranty         2,603           229
# 39  1 Year Manufacturer Warranty         2,603           229
# 40  1 Year Manufacturer Warranty         1,981           154
# 41  1 Year Manufacturer Warranty         2,603           229
# 42  1 Year Manufacturer Warranty           583            51
# 43  1 Year Manufacturer Warranty           500            44
# 44  1 Year Manufacturer Warranty         2,603           229
# 45  1 Year Manufacturer Warranty           195            15
# 46  1 Year Manufacturer Warranty           448            41
# 47  1 Year Manufacturer Warranty           500            44
#
#                                              Features
# 0   GPS and Altimeter,Swimproof,Voice Based Siri,3...
# 1   GPS and Altimeter,Swimproof,Voice Based Siri,3...
# 2   GPS and Altimeter,Swimproof,Voice Based Siri,3...
# 3   GPS and Altimeter,Swimproof,Voice Based Siri,3...
# 4   Large Retina OLED display,attend calls and rep...
# 5   GPS + Cellular model lets you call, text and g...
# 6   Attend calls and reply to messages using the G...
# 7   Attend calls and reply to messages using the G...
# 8   Attend calls and reply to messages using the G...
# 9   GPS + Cellular model lets you call, text and g...
# 10  Large Retina OLED display,attend calls and rep...
# 11  GPS + Cellular model lets you call, text and g...
# 12  Attend calls and reply to messages using the G...
# 13  Attend calls and reply to messages using the G...
# 14  GPS + Cellular model lets you call, text and g...
# 15  GPS + Cellular model lets you call, text and g...
# 16  GPS + Cellular model lets you call, text and g...
# 17  GPS + Cellular model lets you call, text and g...
# 18  GPS + Cellular model lets you call, text and g...
# 19  GPS + Cellular model lets you call, text and g...
# 20  Large Retina OLED display,attend calls and rep...
# 21  GPS + Cellular model lets you call, text and g...
# 22  Large Retina OLED display,attend calls and rep...
# 23  Large Retina OLED display,attend calls and rep...
# 24  GPS and Altimeter,Swimproof,Voice Based Siri,3...
# 25  GPS and Altimeter,Swimproof,Voice Based Siri,3...
# 26  GPS and Altimeter,Swimproof,Voice Based Siri,3...
# 27  Large Retina OLED display,attend calls and rep...
# 28  GPS + Cellular model lets you call, text and g...
# 29  GPS + Cellular model lets you call, text and g...
# 30  Large Retina OLED display,attend calls and rep...
# 31  Attend calls and reply to messages using the G...
# 32  GPS + Cellular model lets you call, text and g...
# 33  GPS + Cellular model lets you call, text and g...
# 34  Attend calls and reply to messages using the G...
# 35  GPS + Cellular model lets you call, text and g...
# 36  GPS + Cellular model lets you call, text and g...
# 37  GPS + Cellular model lets you call, text and g...
# 38  Large Retina OLED display,attend calls and rep...
# 39  Large Retina OLED display,attend calls and rep...
# 40  GPS + Cellular model lets you call, text and g...
# 41  Large Retina OLED display,attend calls and rep...
# 42  Attend calls and reply to messages using the G...
# 43  GPS + Cellular model lets you call, text and g...
# 44  Large Retina OLED display,attend calls and rep...
# 45  GPS + Cellular model lets you call, text and g...
# 46  OLED Always-on Retina Display with Force Touch...
# 47  GPS + Cellular model lets you call, text and g...

# %%
data.to_csv('C:/balaji bca a/WEB SCRAPPING FLIPKART PYTHON MACBOOK PROGRAM.csv')
